# %%
import pandas as pd
from datetime import datetime

# %%
print(datetime.strptime('2016-03-01 00:00:00','%Y-%m-%d %H:%M:%S') - \
      datetime.strptime('2016-03-01 00:07:55','%Y-%m-%d %H:%M:%S')
)
# Out:
# -1 day, 23:52:05

# %%
data = pd.read_csv("./uber_data.csv")
df = data[data['tpep_pickup_datetime'] != 0]
df['tout_time'] = df.apply(lambda row: (datetime.strptime(str(row[2]), '%Y-%m-%d %H:%M:%S') - \
                                        datetime.strptime(str(row[1]), '%Y-%m-%d %H:%M:%S') ).total_seconds()/60, axis = 1)
# print(df['tout_time'].head)
df['tout_time'].plot.bar()
# Out:
# /var/folders/y6/z55g0m8n1kng_3_nx6qdnywm0000gn/T/ipykernel_15856/452164250.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df['tout_time'] = df.apply(lambda row: (datetime.strptime(str(row[2]), '%Y-%m-%d %H:%M:%S') - \
# /var/folders/y6/z55g0m8n1kng_3_nx6qdnywm0000gn/T/ipykernel_15856/452164250.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   datetime.strptime(str(row[1]), '%Y-%m-%d %H:%M:%S') ).total_seconds()/60, axis = 1)
# <Axes: >
# Error in callback <function flush_figures at 0x12fc50a40> (for post_execute), with arguments args (),kwargs {}:
# ...
